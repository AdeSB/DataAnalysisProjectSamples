# %%
# Import Pandas library
# Read and show the csv file from local computer, named "WHO_stats.csv".

import pandas as pd
df = pd.read_csv("C:/Users/User/Documents/PORTFOLIO PROJECT/DATASETS/WHO_stats.csv")
print(df)
# Out:
#                                 Country                 Region  Population  \
# 0                           Afghanistan  Eastern Mediterranean       29825
# 1                               Albania                 Europe        3162
# 2                               Algeria                 Africa       38482
# 3                               Andorra                 Europe          78
# 4                                Angola                 Africa       20821
# ..                                  ...                    ...         ...
# 189  Venezuela (Bolivarian Republic of)               Americas       29955
# 190                            Viet Nam        Western Pacific       90796
# 191                               Yemen  Eastern Mediterranean       23852
# 192                              Zambia                 Africa       14075
# 193                            Zimbabwe                 Africa       13724
#
# ...

# %%
# Showing up the most top records from CSV data (Ascending)

df.head()
# Out:
#        Country                 Region  Population  Under15  Over60  \
# 0  Afghanistan  Eastern Mediterranean       29825    47.42    3.82
# 1      Albania                 Europe        3162    21.33   14.93
# 2      Algeria                 Africa       38482    27.42    7.17
# 3      Andorra                 Europe          78    15.20   22.86
# 4       Angola                 Africa       20821    47.58    3.84
#
#    FertilityRate  LifeExpectancy  ChildMortality  CellularSubscribers  \
# 0           5.40              60            98.5                54.26
# 1           1.75              74            16.7                96.39
# 2           2.83              73            20.0                98.99
# 3            NaN              82             3.2                75.49
# 4           6.10              51           163.5                48.38
#
#    LiteracyRate     GNI  PrimarySchoolEnrollmentMale  \
# 0           NaN  1140.0                          NaN
# ...

# %%
# Showing up the most bottom records from CSV data (Ascending)

df.tail()
# Out:
#                                 Country                 Region  Population  \
# 189  Venezuela (Bolivarian Republic of)               Americas       29955
# 190                            Viet Nam        Western Pacific       90796
# 191                               Yemen  Eastern Mediterranean       23852
# 192                              Zambia                 Africa       14075
# 193                            Zimbabwe                 Africa       13724
#
#      Under15  Over60  FertilityRate  LifeExpectancy  ChildMortality  \
# 189    28.84    9.17           2.44              75            15.3
# 190    22.87    9.32           1.79              75            23.0
# 191    40.72    4.54           4.35              64            60.0
# 192    46.73    3.95           5.77              55            88.5
# 193    40.24    5.68           3.64              54            89.8
#
#      CellularSubscribers  LiteracyRate      GNI  PrimarySchoolEnrollmentMale  \
# ...

# %%
# Showing up the structure of the dataset. The dataset consists of 194 entries with 13 variables and 3 data types (object, int64, and float)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        194 non-null    object
#  1   Region                         194 non-null    object
#  2   Population                     194 non-null    int64
#  3   Under15                        194 non-null    float64
#  4   Over60                         194 non-null    float64
#  5   FertilityRate                  183 non-null    float64
#  6   LifeExpectancy                 194 non-null    int64
#  7   ChildMortality                 194 non-null    float64
#  8   CellularSubscribers            184 non-null    float64
#  9   LiteracyRate                   103 non-null    float64
#  10  GNI                            162 non-null    float64
#  11  PrimarySchoolEnrollmentMale    101 non-null    float64
# ...

# %%
# Let Python describes the dataset by summarize the statistics of the dataset

df.describe()
# Out:
#          Population     Under15      Over60  FertilityRate  LifeExpectancy  \
# count  1.940000e+02  194.000000  194.000000     183.000000      194.000000
# mean   3.635997e+04   28.732423   11.163660       2.940656       70.010309
# std    1.379031e+05   10.534573    7.149331       1.480984        9.259075
# min    1.000000e+00   13.120000    0.810000       1.260000       47.000000
# 25%    1.695750e+03   18.717500    5.200000       1.835000       64.000000
# 50%    7.790000e+03   28.650000    8.530000       2.400000       72.500000
# 75%    2.453525e+04   37.752500   16.687500       3.905000       76.000000
# max    1.390000e+06   49.990000   31.920000       7.580000       83.000000
#
#        ChildMortality  CellularSubscribers  LiteracyRate           GNI  \
# count      194.000000           184.000000    103.000000    162.000000
# mean        36.148969            93.641522     83.710680  13320.925926
# std         37.992935            41.400447     17.530645  15192.988650
# ...

# %%
# Checking column with missing value. There are six columns with missing values. Need to clean it first.

print(df.isnull().any())
# Out:
# Country                          False
# Region                           False
# Population                       False
# Under15                          False
# Over60                           False
# FertilityRate                     True
# LifeExpectancy                   False
# ChildMortality                   False
# CellularSubscribers               True
# LiteracyRate                      True
# GNI                               True
# PrimarySchoolEnrollmentMale       True
# PrimarySchoolEnrollmentFemale     True
# dtype: bool

# %%
# Drop any missing values from the dataset

df = df.dropna(axis = 0, how = "any")

# %%
# Recheck dataset after dropping missing values

print(df.isnull().any())
# Out:
# Country                          False
# Region                           False
# Population                       False
# Under15                          False
# Over60                           False
# FertilityRate                    False
# LifeExpectancy                   False
# ChildMortality                   False
# CellularSubscribers              False
# LiteracyRate                     False
# GNI                              False
# PrimarySchoolEnrollmentMale      False
# PrimarySchoolEnrollmentFemale    False
# dtype: bool

# %%
# Recheck dataset structure and finding out that only 50 entries left.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 4 to 192
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        50 non-null     object
#  1   Region                         50 non-null     object
#  2   Population                     50 non-null     int64
#  3   Under15                        50 non-null     float64
#  4   Over60                         50 non-null     float64
#  5   FertilityRate                  50 non-null     float64
#  6   LifeExpectancy                 50 non-null     int64
#  7   ChildMortality                 50 non-null     float64
#  8   CellularSubscribers            50 non-null     float64
#  9   LiteracyRate                   50 non-null     float64
#  10  GNI                            50 non-null     float64
#  11  PrimarySchoolEnrollmentMale    50 non-null     float64
# ...

# %%
# Recalculate statistical values on the dataset. Pretty much differ from the first calculation.

df.describe()
# Out:
#           Population    Under15     Over60  FertilityRate  LifeExpectancy  \
# count      50.000000  50.000000  50.000000      50.000000       50.000000
# mean    18646.380000  29.008000  11.592200       3.041800       68.640000
# std     30225.767505  12.040371   8.091328       1.663171       10.239499
# min        89.000000  13.280000   1.730000       1.260000       48.000000
# 25%      2854.000000  15.322500   4.957500       1.490000       59.500000
# 50%      7972.500000  29.355000   7.530000       2.415000       73.500000
# 75%     21590.750000  40.182500  20.520000       4.492500       75.750000
# max    169000.000000  48.540000  26.970000       6.850000       82.000000
#
#        ChildMortality  CellularSubscribers  LiteracyRate           GNI  \
# count       50.000000            50.000000      50.00000     50.000000
# mean        40.350000            98.433800      85.11000  11913.200000
# std         43.577055            40.422083      18.02588  14166.387992
# ...

# %%
# Further exploration on the Population variable. Finding out the most population in the dataset

df.loc[df['Population'].idxmax()]
# Out:
# Country                          Nigeria
# Region                            Africa
# Population                        169000
# Under15                            44.23
# Over60                              4.49
# FertilityRate                       6.02
# LifeExpectancy                        53
# ChildMortality                     123.7
# CellularSubscribers                58.58
# LiteracyRate                        61.3
# GNI                               2290.0
# PrimarySchoolEnrollmentMale         60.1
# PrimarySchoolEnrollmentFemale       54.8
# Name: 124, dtype: object

# %%
# Explore the lowest population on the dataset

df.loc[df['Population'].idxmin()]
# Out:
# Country                          Antigua and Barbuda
# Region                                      Americas
# Population                                        89
# Under15                                        25.96
# Over60                                         12.35
# FertilityRate                                   2.12
# LifeExpectancy                                    75
# ChildMortality                                   9.9
# CellularSubscribers                           196.41
# LiteracyRate                                    99.0
# GNI                                          17900.0
# PrimarySchoolEnrollmentMale                     91.1
# PrimarySchoolEnrollmentFemale                   84.5
# Name: 5, dtype: object

# %%
# Explore the highest country in Literacy Rate
# Estonia has 99.8 Literacy Rate

df.loc[df['LiteracyRate'].idxmax()]
# Out:
# Country                          Estonia
# Region                            Europe
# Population                          1291
# Under15                            15.69
# Over60                             23.92
# FertilityRate                       1.62
# LifeExpectancy                        76
# ChildMortality                       3.6
# CellularSubscribers               138.98
# LiteracyRate                        99.8
# GNI                              20850.0
# PrimarySchoolEnrollmentMale         97.7
# PrimarySchoolEnrollmentFemale       97.0
# Name: 57, dtype: object

# %%
# Explore the lowest country in Literacy Rate
# Mali has 31.1 Literacy Rate

df.loc[df['LiteracyRate'].idxmin()]
# Out:
# Country                            Mali
# Region                           Africa
# Population                        14854
# Under15                           47.14
# Over60                             4.29
# FertilityRate                      6.85
# LifeExpectancy                       51
# ChildMortality                    128.0
# CellularSubscribers               68.32
# LiteracyRate                       31.1
# GNI                              1040.0
# PrimarySchoolEnrollmentMale        70.6
# PrimarySchoolEnrollmentFemale      60.8
# Name: 104, dtype: object

# %%
# Explore the Highest country in Gross National Income (in USD)
# Qatar has USD 86440 on GNI

df.loc[df['GNI'].idxmax()]
# Out:
# Country                                          Qatar
# Region                           Eastern Mediterranean
# Population                                        2051
# Under15                                          13.28
# Over60                                            1.73
# FertilityRate                                     2.06
# LifeExpectancy                                      82
# ChildMortality                                     7.4
# CellularSubscribers                             123.11
# LiteracyRate                                      96.3
# GNI                                            86440.0
# PrimarySchoolEnrollmentMale                       95.7
# PrimarySchoolEnrollmentFemale                     96.6
# Name: 137, dtype: object

# %%
# Explore the lowest country in Gross National Income (in USD)
# Eritrea has just USD580 on GNI

df.loc[df['GNI'].idxmin()]
# Out:
# Country                          Eritrea
# Region                            Africa
# Population                          6131
# Under15                             43.1
# Over60                              3.73
# FertilityRate                       4.88
# LifeExpectancy                        61
# ChildMortality                      51.8
# CellularSubscribers                 4.47
# LiteracyRate                        67.8
# GNI                                580.0
# PrimarySchoolEnrollmentMale         37.2
# PrimarySchoolEnrollmentFemale       32.5
# Name: 56, dtype: object

# %%
# Explore the highest country in population with over 60 years age
# Italy has 26,97% of the population over 60 years old,
# with life expectacy 82 percent;
# Gross National Income (GNI) USD 32,400; and
# Literacy Rate 98.9

df.loc[df['Over60'].idxmax()]
# Out:
# Country                            Italy
# Region                            Europe
# Population                         60885
# Under15                            14.04
# Over60                             26.97
# FertilityRate                       1.45
# LifeExpectancy                        82
# ChildMortality                       3.8
# CellularSubscribers               157.93
# LiteracyRate                        98.9
# GNI                              32400.0
# PrimarySchoolEnrollmentMale         99.6
# PrimarySchoolEnrollmentFemale       98.5
# Name: 83, dtype: object

# %%
# Explore the lowest country in population with over 60 years age
# Qatar has only 1.73% of the population over 60 years old,
# but with life expectacy 82 percent;
# Gross National Income (GNI) USD 86,440; and
# Literacy Rate 96.3

df.loc[df['Over60'].idxmin()]
# Out:
# Country                                          Qatar
# Region                           Eastern Mediterranean
# Population                                        2051
# Under15                                          13.28
# Over60                                            1.73
# FertilityRate                                     2.06
# LifeExpectancy                                      82
# ChildMortality                                     7.4
# CellularSubscribers                             123.11
# LiteracyRate                                      96.3
# GNI                                            86440.0
# PrimarySchoolEnrollmentMale                       95.7
# PrimarySchoolEnrollmentFemale                     96.6
# Name: 137, dtype: object

# %%
# Now we have several information about the dataset, to make a useful insight about data,
# I want to visualize the correlation between Literacy Rate and GNI 

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['LiteracyRate'], df['GNI'])
ax.set_xlabel('Literacy Rate')
ax.set_ylabel('Gross National Income (USD)')
# Out:
# Text(0, 0.5, 'Gross National Income (USD)')

# %%
# Just for fun ;) , is there any relationship between wealthiness and healthiness? or
# Here I visualize correlation between Over 60 and GNI

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['Over60'], df['GNI'])
ax.set_xlabel('Older Citizen in Population (%)')
ax.set_ylabel('Gross National Income (USD)')
# Out:
# Text(0, 0.5, 'Gross National Income (USD)')
